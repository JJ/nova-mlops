# %%
# !pip install pandas pyarrow seaborn matplotlib

# %%
import pandas as pd
deltas = pd.read_parquet("ukr-mod-deltas.parquet")
# Out:
#           Date   aircraft   Anti-aircraft warfare systems   APV  \
# 0   2022-04-12          0                               0     0
# 1   2022-04-13          1                               1    18
# 2   2022-04-14          2                               0     4
# 3   2022-04-15          3                               2     8
# 4   2022-04-16          0                               0     6
# ..         ...        ...                             ...   ...
# 66  2022-07-03          0                               0     7
# 67  2022-07-04          0                               0    10
# 68  2022-07-05          0                               0    18
# 69  2022-07-06          0                               2    17
# 70  2022-07-07          0                               0     8
#
#      artillery systems   helicopters   MLRS   personnel   special equipment  \
# 0                    0             0      0           0                   0
# ...

# %%
import matplotlib as plt
import seaborn as sb
sb.set_theme(style="darkgrid")
sb.relplot(x="Date",y=" tanks", data=deltas)
